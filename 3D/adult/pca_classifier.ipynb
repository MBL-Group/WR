# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np



data3 = pd.read_csv('984.csv')  
data4 = pd.read_csv('N2.csv')   




data3['Group'] = '984'
data4['Group'] = 'N2'


data = pd.concat([data3, data4])  


variables = ['area', 'volume', 'length', 'max_width', 'ratio']


X = data[variables]
y = data['Group']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)


le = LabelEncoder()
y_encoded = le.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(X_pca, y_encoded, test_size=0.2, random_state=42)


model = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs', max_iter=100, multi_class='multinomial', class_weight=None, random_state=None)
model.fit(X_train, y_train)


x_min, x_max = X_pca[:, 0].min(), X_pca[:, 0].max()
y_min, y_max = X_pca[:, 1].min(), X_pca[:, 1].max()


size_dict = {'984': 80, 'N2': 80}
sizes = [size_dict[val] for val in y]



custom_palette = ['red', 'orange', 'blue', 'green']
custom_colors = [(0, 0, 1), (0, 1, 1)] 
custom_cmap = plt.cm.colors.ListedColormap(custom_colors)

plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette=custom_colors, sizes=sizes, alpha=1)
scatter = plt.scatter(x=X_pca[:, 0], y=X_pca[:, 1], c=y_encoded, cmap=custom_cmap, s=sizes, alpha=1)



xx, yy = np.meshgrid(np.linspace(x_min-0.1, x_max+0.1, 255), np.linspace(y_min-0.1, y_max+0.1, 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


custom_cmap = plt.cm.colors.ListedColormap(custom_colors)
plt.contourf(xx, yy, Z, cmap=custom_cmap, alpha=0.1)



plt.title('PCA with Logistic Regression')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')


plt.savefig('elegans_pca_n2_984.svg', format='svg')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np



data2 = pd.read_csv('634.csv')  

data4 = pd.read_csv('N2.csv')   



data2['Group'] = '634'

data4['Group'] = 'N2'


data = pd.concat([data2, data4])  


variables = ['area', 'volume', 'length', 'max_width', 'ratio']


X = data[variables]
y = data['Group']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)


le = LabelEncoder()
y_encoded = le.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(X_pca, y_encoded, test_size=0.2, random_state=42)


model = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs', max_iter=100, multi_class='multinomial', class_weight=None, random_state=None)
model.fit(X_train, y_train)


x_min, x_max = X_pca[:, 0].min(), X_pca[:, 0].max()
y_min, y_max = X_pca[:, 1].min(), X_pca[:, 1].max()


size_dict = {'634': 80, 'N2': 80}
sizes = [size_dict[val] for val in y]



custom_palette = ['red', 'orange', 'blue', 'green']

custom_colors = [(0, 1, 0), (0, 1, 1)] 
custom_cmap = plt.cm.colors.ListedColormap(custom_colors)

plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette=custom_colors, sizes=sizes, alpha=1)
scatter = plt.scatter(x=X_pca[:, 0], y=X_pca[:, 1], c=y_encoded, cmap=custom_cmap, s=sizes, alpha=1)



xx, yy = np.meshgrid(np.linspace(x_min-0.1, x_max+0.1, 255), np.linspace(y_min-0.1, y_max+0.1, 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


custom_cmap = plt.cm.colors.ListedColormap(custom_colors)
plt.contourf(xx, yy, Z, cmap=custom_cmap, alpha=0.1)



plt.title('PCA with Logistic Regression')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')


plt.savefig('elegans_pca_n2_634.svg', format='svg')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np


data1 = pd.read_csv('624.csv')  


data4 = pd.read_csv('N2.csv')   


data1['Group'] = '624'


data4['Group'] = 'N2'


data = pd.concat([data1, data4])  


variables = ['area', 'volume', 'length', 'max_width', 'ratio']


X = data[variables]
y = data['Group']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)


le = LabelEncoder()
y_encoded = le.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(X_pca, y_encoded, test_size=0.2, random_state=42)


model = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs', max_iter=100, multi_class='multinomial', class_weight=None, random_state=None)
model.fit(X_train, y_train)


x_min, x_max = X_pca[:, 0].min(), X_pca[:, 0].max()
y_min, y_max = X_pca[:, 1].min(), X_pca[:, 1].max()


size_dict = {'624': 80, 'N2': 80}
sizes = [size_dict[val] for val in y]



custom_palette = ['red', 'orange', 'blue', 'green']

custom_colors = [(1, 0, 0), (0, 1, 1)] 
custom_cmap = plt.cm.colors.ListedColormap(custom_colors)

plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette=custom_colors, sizes=sizes, alpha=1)
scatter = plt.scatter(x=X_pca[:, 0], y=X_pca[:, 1], c=y_encoded, cmap=custom_cmap, s=sizes, alpha=1)



xx, yy = np.meshgrid(np.linspace(x_min-0.1, x_max+0.1, 255), np.linspace(y_min-0.1, y_max+0.1, 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


custom_cmap = plt.cm.colors.ListedColormap(custom_colors)
plt.contourf(xx, yy, Z, cmap=custom_cmap, alpha=0.1)



plt.title('PCA with Logistic Regression')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')


plt.savefig('elegans_pca_n2_624.svg', format='svg')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np



data2 = pd.read_csv('634.csv')  
data3 = pd.read_csv('984.csv')  




data2['Group'] = '634'
data3['Group'] = '984'



data = pd.concat([data2, data3])  


variables = ['area', 'volume', 'length', 'max_width', 'ratio']


X = data[variables]
y = data['Group']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)


le = LabelEncoder()
y_encoded = le.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(X_pca, y_encoded, test_size=0.2, random_state=42)


model = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs', max_iter=100, multi_class='multinomial', class_weight=None, random_state=None)
model.fit(X_train, y_train)


x_min, x_max = X_pca[:, 0].min(), X_pca[:, 0].max()
y_min, y_max = X_pca[:, 1].min(), X_pca[:, 1].max()


size_dict = {'634': 80, '984': 80}
sizes = [size_dict[val] for val in y]



custom_palette = ['red', 'orange', 'blue', 'green']

custom_colors = [(0, 1, 0), (0, 0, 1)] 
custom_cmap = plt.cm.colors.ListedColormap(custom_colors)

plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette=custom_colors, sizes=sizes, alpha=1)
scatter = plt.scatter(x=X_pca[:, 0], y=X_pca[:, 1], c=y_encoded, cmap=custom_cmap, s=sizes, alpha=1)



xx, yy = np.meshgrid(np.linspace(x_min-0.1, x_max+0.1, 255), np.linspace(y_min-0.1, y_max+0.1, 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


custom_cmap = plt.cm.colors.ListedColormap(custom_colors)
plt.contourf(xx, yy, Z, cmap=custom_cmap, alpha=0.1)



plt.title('PCA with Logistic Regression')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')


plt.savefig('elegans_pca_634_984.svg', format='svg')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np


data1 = pd.read_csv('624.csv')  

data3 = pd.read_csv('984.csv')  



data1['Group'] = '624'

data3['Group'] = '984'



data = pd.concat([data1, data3])  


variables = ['area', 'volume', 'length', 'max_width', 'ratio']


X = data[variables]
y = data['Group']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)


le = LabelEncoder()
y_encoded = le.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(X_pca, y_encoded, test_size=0.2, random_state=42)


model = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs', max_iter=100, multi_class='multinomial', class_weight=None, random_state=None)
model.fit(X_train, y_train)


x_min, x_max = X_pca[:, 0].min(), X_pca[:, 0].max()
y_min, y_max = X_pca[:, 1].min(), X_pca[:, 1].max()


size_dict = {'624': 80, '984': 80}
sizes = [size_dict[val] for val in y]



custom_palette = ['red', 'orange', 'blue', 'green']

custom_colors = [(1, 0, 0), (0, 0, 1)] 
custom_cmap = plt.cm.colors.ListedColormap(custom_colors)

plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette=custom_colors, sizes=sizes, alpha=1)
scatter = plt.scatter(x=X_pca[:, 0], y=X_pca[:, 1], c=y_encoded, cmap=custom_cmap, s=sizes, alpha=1)



xx, yy = np.meshgrid(np.linspace(x_min-0.1, x_max+0.1, 255), np.linspace(y_min-0.1, y_max+0.1, 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


custom_cmap = plt.cm.colors.ListedColormap(custom_colors)
plt.contourf(xx, yy, Z, cmap=custom_cmap, alpha=0.1)



plt.title('PCA with Logistic Regression')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')


plt.savefig('elegans_pca_624_984.svg', format='svg')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np


data1 = pd.read_csv('624.csv')  
data2 = pd.read_csv('634.csv')  




data1['Group'] = '624'
data2['Group'] = '634'




data = pd.concat([data1, data2])  


variables = ['area', 'volume', 'length', 'max_width', 'ratio']


X = data[variables]
y = data['Group']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)


le = LabelEncoder()
y_encoded = le.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(X_pca, y_encoded, test_size=0.2, random_state=42)


model = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs', max_iter=100, multi_class='multinomial', class_weight=None, random_state=None)
model.fit(X_train, y_train)


x_min, x_max = X_pca[:, 0].min(), X_pca[:, 0].max()
y_min, y_max = X_pca[:, 1].min(), X_pca[:, 1].max()


size_dict = {'624': 80, '634': 80}
sizes = [size_dict[val] for val in y]



custom_palette = ['red', 'orange', 'blue', 'green']

custom_colors = [(1, 0, 0), (0, 1, 0)] 
custom_cmap = plt.cm.colors.ListedColormap(custom_colors)

plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette=custom_colors, sizes=sizes, alpha=1)
scatter = plt.scatter(x=X_pca[:, 0], y=X_pca[:, 1], c=y_encoded, cmap=custom_cmap, s=sizes, alpha=1)



xx, yy = np.meshgrid(np.linspace(x_min-0.1, x_max+0.1, 255), np.linspace(y_min-0.1, y_max+0.1, 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


custom_cmap = plt.cm.colors.ListedColormap(custom_colors)
plt.contourf(xx, yy, Z, cmap=custom_cmap, alpha=0.1)



plt.title('PCA with Logistic Regression')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')


plt.savefig('elegans_pca_624_634.svg', format='svg')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np


data1 = pd.read_csv('624.csv')  
data2 = pd.read_csv('634.csv')  
data3 = pd.read_csv('984.csv')  
data4 = pd.read_csv('N2.csv')   


data1['Group'] = '624'
data2['Group'] = '634'
data3['Group'] = '984'
data4['Group'] = 'N2'


data = pd.concat([data1, data2, data3, data4])  


variables = ['area', 'volume', 'length', 'max_width', 'ratio']


X = data[variables]
y = data['Group']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)


le = LabelEncoder()
y_encoded = le.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(X_pca, y_encoded, test_size=0.2, random_state=42)


model = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs', max_iter=100, multi_class='multinomial', class_weight=None, random_state=None)
model.fit(X_train, y_train)


x_min, x_max = X_pca[:, 0].min(), X_pca[:, 0].max()
y_min, y_max = X_pca[:, 1].min(), X_pca[:, 1].max()


size_dict = {'624': 80, '634': 80, '984': 80, 'N2': 80}
sizes = [size_dict[val] for val in y]



custom_palette = ['red', 'orange', 'blue', 'green']
custom_colors = [(1, 0, 0), (0, 1, 0), (0, 0, 1), (0, 1, 1)] 
custom_cmap = plt.cm.colors.ListedColormap(custom_colors)

plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette=custom_colors, sizes=sizes, alpha=1)
scatter = plt.scatter(x=X_pca[:, 0], y=X_pca[:, 1], c=y_encoded, cmap=custom_cmap, s=sizes, alpha=1)



xx, yy = np.meshgrid(np.linspace(x_min-0.1, x_max+0.1, 255), np.linspace(y_min-0.1, y_max+0.1, 100))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


custom_cmap = plt.cm.colors.ListedColormap(custom_colors)
plt.contourf(xx, yy, Z, cmap=custom_cmap, alpha=0.1)



plt.title('PCA with Logistic Regression')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')


plt.savefig('elegans_pca_624_634_984_N2.svg', format='svg')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np




X_train, X_test, y_train, y_test = train_test_split(X_pca, y_encoded, test_size=0.3, random_state=42)


svm_classifier = SVC(C=18.0, kernel='rbf', degree=50, gamma='auto', 
					coef0=0.0, shrinking=True, probability=False, tol=0.001, 
					cache_size=200, class_weight=None, verbose=False, max_iter=-1, 
					decision_function_shape='ovr', random_state=None)
svm_classifier.fit(X_train, y_train)


y_pred_svm = svm_classifier.predict(X_test)



custom_palette = [(215,25,28), (253,174,97), (171,221,164), (43,131,186)]

custom_colors_normalized = np.array(custom_palette) / 255.0


size_dict = {'624': 80, '634': 80,'984': 80, 'N2': 80}
sizes = [size_dict[val] for val in y]

plt.figure(figsize=(10, 8))
custom_colors = [(1, 0, 0), (0, 1, 0), (0, 0, 1), (0, 1, 1)] 
custom_cmap = plt.cm.colors.ListedColormap(custom_colors)

sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette=custom_colors, markers=['o', 's', '^', 'D'], alpha=0.7)
scatter = plt.scatter(x=X_pca[:, 0], y=X_pca[:, 1], c=y_encoded, cmap=custom_cmap, s=sizes, alpha=1)



xx, yy = np.meshgrid(np.linspace(x_min-0.1, x_max+0.05, 100), np.linspace(y_min-0.05, y_max+0.1, 100))
Z = svm_classifier.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)



custom_colors = [(1, 0, 0), (0, 1, 0), (0, 0, 1), (0, 1, 1)]  


custom_cmap = plt.cm.colors.ListedColormap(custom_colors)



plt.contourf(xx, yy, Z, cmap=custom_cmap, alpha=0.1)



plt.title('PCA with SVM Classifier')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')


plt.savefig('elegans_pca_624_634_984_N2_svm.svg', format='svg')

plt.show()
