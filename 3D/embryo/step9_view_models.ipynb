# %%
import open3d as o3d
import numpy as np
import cv2
import math
import time



pcd = o3d.io.read_triangle_mesh("8th__origin_filter_surface.ply")

pcd.compute_vertex_normals()


vis = o3d.visualization.Visualizer()
vis.create_window()



render_option = vis.get_render_option()
render_option.point_size = 1
render_option.background_color = np.asarray([0, 0, 0])

render_option.light_on = True






time.sleep(2)

vis.add_geometry(pcd)
vis.poll_events()
vis.update_renderer()

time.sleep(2)



for i in range(360):

    theta = 1.0*math.radians((1))

    R = pcd.get_rotation_matrix_from_xyz((0, theta, 0))

    pcd.rotate(R) 


    vis.update_geometry(pcd)


    
    
    

    vis.poll_events()
    vis.update_renderer()

    cv2.waitKey(20)

time.sleep(2)
vis.destroy_window()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import open3d as o3d
import numpy as np
import cv2
import math
import time



pcd = o3d.io.read_point_cloud("30th__origin.ply")



vis = o3d.visualization.Visualizer()
vis.create_window()



render_option = vis.get_render_option()
render_option.point_size = 1
render_option.background_color = np.asarray([0, 0, 0])

render_option.light_on = True






time.sleep(2)

vis.add_geometry(pcd)
vis.poll_events()
vis.update_renderer()

time.sleep(2)



for i in range(360):

    theta = 1.0*math.radians((1))

    R = pcd.get_rotation_matrix_from_xyz((0, theta, 0))

    pcd.rotate(R) 


    vis.update_geometry(pcd)


    
    
    

    vis.poll_events()
    vis.update_renderer()

    cv2.waitKey(20)

time.sleep(2)
vis.destroy_window()

# %%
import open3d as o3d
import numpy as np
import cv2
import math
import time




pcd = o3d.io.read_triangle_mesh("0-origin.ply")

pcd.compute_vertex_normals()


o3d.visualization.rendering.Scene.enable_sun_light = True
vis = o3d.visualization.Visualizer()
vis.create_window()



render_option = vis.get_render_option()
render_option.point_size = 1
render_option.background_color = np.asarray([0, 0, 0])

render_option.light_on = True






time.sleep(2)

vis.add_geometry(pcd)
vis.poll_events()
vis.update_renderer()

time.sleep(2)



for i in range(360):

    theta = 1.0*math.radians((1))

    R = pcd.get_rotation_matrix_from_xyz((0, theta, 0))

    pcd.rotate(R) 


    vis.update_geometry(pcd)


    
    
    

    vis.poll_events()
    vis.update_renderer()

    cv2.waitKey(20)

time.sleep(2)
vis.destroy_window()

# %%
import open3d as o3d
import numpy as np
import cv2
import math
import time



pcd = o3d.io.read_triangle_mesh("30th__tietu_filter_surface.ply")

o3d.visualization.rendering.Scene.enable_sun_light = True
